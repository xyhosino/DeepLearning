# %% [markdown]
# <a href="https://colab.research.google.com/github/xyhosino/DeepLearning/blob/main/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0%E6%88%BF%E4%BB%B7%E9%A2%84%E6%B5%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_housing = pd.read_csv("/content/sample_data/house.csv")
df_housing.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
x = df_housing.drop("median_house_value", axis = 1)
y = df_housing.median_house_value

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
print('房价的真值（测试集）', y_test)
print('房价的预测值（测试集）', y_pred)
# Out:
# 房价的真值（测试集） 3873     171400.0
# 3625     189600.0
# 3028     500001.0
# 13814    229400.0
# 15398    163400.0
#            ...
# 1363     212500.0
# 7947     210500.0
# 14574    142900.0
# 10009    128300.0
# 9149      84700.0
# Name: median_house_value, Length: 3400, dtype: float64
# 房价的预测值（测试集） [211157.06335416 218581.64298576 465317.31295564 ... 201751.23969632
#  160873.51846958 138847.26913351]

# %%
print(model.score(x_test, y_test))
# Out:
# 0.6321014171579528

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test.median_income, y_test, color='brown')
plt.plot(x_test.median_income, y_pred, color='green', linewidth=1)
plt.xlabel("Median Income")
plt.ylabel("Median House Value")
plt.show()
